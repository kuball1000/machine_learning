# %% [markdown]
# <a href="https://colab.research.google.com/github/kuball1000/machine_learning/blob/main/Ekstracja_cech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
def fetch_financial_data(company="AMZN"):
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open     High     Low   Close    Volume
# Date
# 2024-03-04  177.530  180.140  177.50  177.52  37314839
# 2024-03-01  176.750  178.725  176.07  178.22  31981152
# 2024-02-29  173.010  177.220  172.85  176.76  53805359
# 2024-02-28  172.440  174.050  172.27  173.16  28180482
# 2024-02-27  174.075  174.620  172.86  173.54  31141732

# %%
df = df_raw.copy()

df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                 Open      High       Low     Close    Volume  day  month  year
# Date
# 2024-03-04  177.5300  180.1400  177.5000  177.5200  37314839    4      3  2024
# 2024-03-01  176.7500  178.7250  176.0700  178.2200  31981152    1      3  2024
# 2024-02-29  173.0100  177.2200  172.8500  176.7600  53805359   29      2  2024
# 2024-02-28  172.4400  174.0500  172.2700  173.1600  28180482   28      2  2024
# 2024-02-27  174.0750  174.6200  172.8600  173.5400  31141732   27      2  2024
# ...              ...       ...       ...       ...       ...  ...    ...   ...
# 2019-03-12   83.4500   84.2135   83.0490   83.6550  72289960   12      3  2019
# 2019-03-11   81.3060   83.6145   81.3005   83.5310  77527040   11      3  2019
# 2019-03-08   80.2005   81.1360   79.3285   81.0400  93340280    8      3  2019
# 2019-03-07   83.3685   83.4875   81.0255   81.2975  99140340    7      3  2019
# 2019-03-06   84.7985   84.8875   83.4140   83.4475  79920020    6      3  2019
#
# ...

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})

#df['height_cat1'] = pd.cut(x=df.height, bins=3)
df['height_cat2'] = pd.cut(x=df.height, bins=(165,175,185,195), labels=['small', 'medium', 'high'])

df
# Out:
#    height height_cat2
# 0   175.0       small
# 1   178.5      medium
# 2   185.0      medium
# 3   191.0        high
# 4   184.5      medium
# 5   183.0      medium
# 6   168.0       small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_high
# 0   175.0              0            0
# 1   178.5              1            0
# 2   185.0              1            0
# 3   191.0              0            1
# 4   184.5              1            0
# 5   183.0              1            0
# 6   168.0              0            0

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})

new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
